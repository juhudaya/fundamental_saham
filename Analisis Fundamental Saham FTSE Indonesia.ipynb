# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
tickers = ['BBCA.JK', 'ASII.JK', 'TLKM.JK', 'BMRI.JK', 'UNVR.JK', 'BBRI.JK', 'TOWR.JK', 'UNTR.JK', 'INDF.JK', 'BBNI.JK']

# %%
tickers
# Out:
# ['BBCA.JK',
#  'ASII.JK',
#  'TLKM.JK',
#  'BMRI.JK',
#  'UNVR.JK',
#  'BBRI.JK',
#  'TOWR.JK',
#  'UNTR.JK',
#  'INDF.JK',
#  'BBNI.JK']

# %%
infos =[]

for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
infos
# Out:
# [{'zip': '10310',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 25066,
#   'longBusinessSummary': 'PT Bank Central Asia Tbk, together with its subsidiaries, provides banking products and services to individual, corporate, and small and medium enterprise customers in Indonesia and internationally. It offers savings accounts; motorcycle financing, as well as car, housing, working capital, and investment loans; mutual funds and bonds; electronic money services; credit cards; business collection services; and home and eBanking, remittance, and customer services. The company also provides investment financing, working capital financing, auto and multipurpose financing, operating lease, other financing activities, money lending and remittance, securities brokerage dealing and securities issuance underwriting, general or loss insurance, life insurance, Sharia banking, and venture capital services. As of December 2021, it operated 1,334 offices comprising 137 main branch offices; 1,105 permanent sub-branch offices; 70 mobile sub-branch offices; and 22 functional offices, as well as total 18,034 automated teller machines (ATMs) consisting of cash recycling machines and multi-functional ATMs. PT Bank Central Asia Tbk was founded in 1955 and is headquartered in Jakarta, Indonesia. PT Bank Central Asia Tbk is a subsidiary of PT Dwimuria Investama Andalan.',
#   'city': 'Jakarta',
#   'phone': '62 21 2358 8000',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.bca.co.id',
#   'maxAge': 1,
#   'address1': 'Menara BCA',
#   'fax': '62 21 2358 8300',
#   'industry': 'Banks—Regional',
#   'address2': 'Grand Indonesia Jl. M.H. Thamrin No. 1',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.45747003,
#   'grossMargins': 0,
#   'operatingCashflow': -30998108569600,
#   'revenueGrowth': 0.112,
#   'operatingMargins': 0.56556,
#   'ebitda': None,
#   'targetLowPrice': 6400,
#   'recommendationKey': 'hold',
#   'grossProfits': 67256960000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 8390,
#   'currentPrice': 7750,
#   'earningsGrowth': 0.14,
#   'currentRatio': None,
#   'returnOnAssets': 0.02763,
#   'numberOfAnalystOpinions': 21,
#   'targetMeanPrice': 8322.3,
#   'debtToEquity': None,
#   'returnOnEquity': 0.17377001,
#   'targetHighPrice': 9900,
#   'totalCash': 296449883504640,
#   'totalDebt': 2390317072384,
#   'totalRevenue': 70927157035008,
#   'totalCashPerShare': 2404.784,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 575.357,
#   'quickRatio': None,
#   'recommendationMean': 2.6,
#   'exchange': 'JKT',
#   'shortName': 'Bank Central Asia Tbk.',
#   'longName': 'PT Bank Central Asia Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BBCA.JK',
#   'messageBoardId': 'finmb_1945186',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 9.326,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': 0.18823528,
#   'morningStarRiskRating': None,
#   'forwardEps': 339.71,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 123275001856,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1579.308,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.20536,
#   'netIncomeToCommon': 32447383207936,
#   'trailingEps': 263,
#   'lastDividendValue': 120,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 4.9072127,
#   'heldPercentInsiders': 0.60402,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 51838391276,
#   'beta': 0.55109,
#   'enterpriseValue': 661460866826240,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1634083200,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1648425600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.146,
#   'priceToSalesTrailing12Months': 13.469893,
#   'dateShortInterest': None,
#   'pegRatio': 1.65,
#   'ytdReturn': None,
#   'forwardPE': 22.813578,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 7575,
#   'regularMarketOpen': 7600,
#   'twoHundredDayAverage': 7410.7,
#   'trailingAnnualDividendYield': 0.019141914,
#   'payoutRatio': 0.8798,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 7750,
#   'navPrice': None,
#   'averageDailyVolume10Day': 120037960,
#   'regularMarketPreviousClose': 7575,
#   'fiftyDayAverage': 7790,
#   'trailingAnnualDividendRate': 145,
#   'open': 7600,
#   'toCurrency': None,
#   'averageVolume10days': 120037960,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 145,
#   'exDividendDate': 1648425600,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 7525,
#   'currency': 'IDR',
#   'trailingPE': 29.46768,
#   'regularMarketVolume': 286292700,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 955381249474560,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 112199867,
#   'dayLow': 7525,
#   'ask': 7750,
#   'askSize': 0,
#   'volume': 286292700,
#   'fiftyTwoWeekHigh': 8300,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.35,
#   'fiftyTwoWeekLow': 5905,
#   'bid': 7725,
#   'tradeable': False,
#   'dividendYield': 0.0187,
#   'bidSize': 0,
#   'dayHigh': 7750,
#   'regularMarketPrice': 7750,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bca.co.id'},
#  {'zip': '10220',
#   'sector': 'Consumer Cyclical',
#   'fullTimeEmployees': 124879,
#   'longBusinessSummary': 'PT Astra International Tbk, together with its subsidiaries, operates in the automotive, financial services, heavy equipment, mining, construction, energy, agri, infrastructure and logistics, information technology, and property businesses in Indonesia. It offers cars, trucks, and motorcycles of various brands; manufactures and sells automotive components to the original equipment for manufacturers and replacement markets, as well as provides consultation services to its customers; financing for cars, motorcycles, and heavy equipment; life, vehicle, and health insurance, as well as other insurance for commercial business; and various banking products and services. The company also distributes heavy equipment for the mining, plantation, construction, forestry, transportation, and material handling industries; provides coal mining contracting services; operates coal mines; and produces crude palm oil. In addition, it is involved in the development and operation of toll roads; rental and leasing of vehicles; resale of used cars; and provision of public transportation services and logistics facilities. Further, the company offers various information technology business solutions based on document, information, and communication technology; and engages in the property investment, development, and management activities. Additionally, it is involved in the foundation; formwork and bekisting; pump services; and mechanical, electrical, and plumbing works, as well as dredging, reclamation, and marine works. The company was incorporated in 1957 and is headquartered in Jakarta, Indonesia. PT Astra International Tbk operates as a subsidiary of Jardine Cycle & Carriage Limited.',
#   'city': 'Jakarta',
#   'phone': '62 21 5084 3888',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.astra.co.id',
#   'maxAge': 1,
#   'address1': 'Menara Astra',
#   'fax': '62 21 6530 4957',
#   'industry': 'Auto Parts',
#   'address2': '59 Floor Jl. Jenderal Sudirman Kav 5-6',
#   'ebitdaMargins': 0.1725,
#   'profitMargins': 0.09196,
#   'grossMargins': 0.19441,
#   'operatingCashflow': 36891999076352,
#   'revenueGrowth': 0.39,
#   'operatingMargins': 0.1246,
#   'ebitda': 43755998543872,
#   'targetLowPrice': 5000,
#   'recommendationKey': 'buy',
#   'grossProfits': 44001000000000,
#   'freeCashflow': 25732124246016,
#   'targetMedianPrice': 8050,
#   'currentPrice': 7350,
#   'earningsGrowth': 0.84,
#   'currentRatio': 1.583,
#   'returnOnAssets': 0.053740002,
#   'numberOfAnalystOpinions': 14,
#   'targetMeanPrice': 7648.2,
#   'debtToEquity': 31.214,
#   'returnOnEquity': 0.14124,
#   'targetHighPrice': 8700,
#   'totalCash': 67791998681088,
#   'totalDebt': 70335001001984,
#   'totalRevenue': 253656003772416,
#   'totalCashPerShare': 1674.557,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 6265.586,
#   'quickRatio': 1.242,
#   'recommendationMean': 1.9,
#   'exchange': 'JKT',
#   'shortName': 'Astra International Tbk.',
#   'longName': 'PT Astra International Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'ASII.JK',
#   'messageBoardId': 'finmb_706870',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.365,
#   'beta3Year': None,
#   'enterpriseToEbitda': 7.912,
#   '52WeekChange': 0.3615023,
#   'morningStarRiskRating': None,
#   'forwardEps': 662.62,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 40483598336,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 4427.403,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.15014,
#   'netIncomeToCommon': 23326999183360,
#   'trailingEps': 576.203,
#   'lastDividendValue': 194,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 1.6601155,
#   'heldPercentInsiders': 0.50146,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 20182670582,
#   'beta': 0.648567,
#   'enterpriseValue': 346188121374720,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1338854400,
#   'lastSplitFactor': '10:1',
#   'legalType': None,
#   'lastDividendDate': 1652054400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.84,
#   'priceToSalesTrailing12Months': 1.1730629,
#   'dateShortInterest': None,
#   'pegRatio': 1.02,
#   'ytdReturn': None,
#   'forwardPE': 11.092331,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 7250,
#   'regularMarketOpen': 7250,
#   'twoHundredDayAverage': 6021.875,
#   'trailingAnnualDividendYield': 0.03296552,
#   'payoutRatio': 0.2292,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 7475,
#   'navPrice': None,
#   'averageDailyVolume10Day': 44529320,
#   'regularMarketPreviousClose': 7250,
#   'fiftyDayAverage': 6980,
#   'trailingAnnualDividendRate': 239,
#   'open': 7250,
#   'toCurrency': None,
#   'averageVolume10days': 44529320,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 239,
#   'exDividendDate': 1652054400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 7250,
#   'currency': 'IDR',
#   'trailingPE': 12.755921,
#   'regularMarketVolume': 90800300,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 297554461851648,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 54313116,
#   'dayLow': 7250,
#   'ask': 7350,
#   'askSize': 0,
#   'volume': 90800300,
#   'fiftyTwoWeekHigh': 7700,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 4640,
#   'bid': 7325,
#   'tradeable': False,
#   'dividendYield': 0.0325,
#   'bidSize': 0,
#   'dayHigh': 7475,
#   'regularMarketPrice': 7350,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/astra.co.id'},
#  {'zip': '40133',
#   'sector': 'Communication Services',
#   'fullTimeEmployees': 21099,
#   'longBusinessSummary': "Perusahaan Perseroan (Persero) PT Telekomunikasi Indonesia Tbk provides telecommunications, informatics, and network services worldwide. The company's Mobile segment offers mobile voice, SMS, and mobile broadband services; and digital services, including financial services, video on demand, music, gaming, IoT, big data analytics, and digital advertising services. Its Consumer segment provides fixed voice and broadband services; and IPTV and related consumer digital services. The company's Enterprise segment offers ICT and digital platform that covers enterprise-grade connectivity services, including satellite, IT services, data center and cloud, and business process outsourcing services, as well as CPE trading and managed, cyber security, financial, big data, digital advertising, e-health, managed ATM, and professional services. Its Wholesale and International Business segment provides wholesale voice, managed, A2P SMS, IP transit and connectivity, data center and cloud, security, and value added and digital services; mobile network operator, mobile virtual network operator, and call center services; and tower and infrastructure services to other licensed operator companies and institutions. The company's Others segment offers digital services, such as digital platform, digital content, and e-commerce; and property management services. The company also provides building management and maintenance services, payment, business management consulting and capital venture, health insurance administration, tourism, directory information, telecommunication construction, and multimedia portal services; acts as a civil consultant and developer; and leases offices. As of December 31, 2020, it had approximately 9.1 million fixed wireline subscribers, including 8.0 million fixed broadband subscribers; and 169.5 million cellular subscribers, including 115.9 million mobile broadband subscribers. The company was founded in 1884 and is headquartered in Bandung, Indonesia.",
#   'city': 'Bandung',
#   'phone': '62 22 452 1404',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.telkom.co.id',
#   'maxAge': 1,
#   'address1': 'Jalan Japati No. 1',
#   'fax': '62 22 720 6757',
#   'industry': 'Telecom Services',
#   'ebitdaMargins': 0.46808997,
#   'profitMargins': 0.1721,
#   'grossMargins': 0.62452,
#   'operatingCashflow': 69537001111552,
#   'revenueGrowth': 0.037,
#   'operatingMargins': 0.30482,
#   'ebitda': 67626998956032,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 89680000000000,
#   'freeCashflow': 27276750094336,
#   'targetMedianPrice': None,
#   'currentPrice': 4310,
#   'earningsGrowth': 0.017,
#   'currentRatio': 0.926,
#   'returnOnAssets': 0.10245,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': 41.171,
#   'returnOnEquity': 0.23764999,
#   'targetHighPrice': None,
#   'totalCash': 42570998611968,
#   'totalDebt': 63127001497600,
#   'totalRevenue': 144473002606592,
#   'totalCashPerShare': 429.74,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 1458.407,
#   'quickRatio': 0.787,
#   'recommendationMean': None,
#   'exchange': 'JKT',
#   'shortName': 'Telkom Indonesia (Persero) Tbk.',
#   'longName': 'Perusahaan Perseroan (Persero) PT Telekomunikasi Indonesia Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'TLKM.JK',
#   'messageBoardId': 'finmb_400368',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 3.233,
#   'beta3Year': None,
#   'enterpriseToEbitda': 6.907,
#   '52WeekChange': 0.231884,
#   'morningStarRiskRating': None,
#   'forwardEps': 1.95,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 99062202368,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1290.038,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.20618,
#   'netIncomeToCommon': 24863999787008,
#   'trailingEps': 250.994,
#   'lastDividendValue': 168.01,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 3.340987,
#   'heldPercentInsiders': 0.57752997,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 47241780474,
#   'beta': 0.195382,
#   'enterpriseValue': 467106416033792,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1377648000,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1623196800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.017,
#   'priceToSalesTrailing12Months': 2.9552796,
#   'dateShortInterest': None,
#   'pegRatio': 33640.2,
#   'ytdReturn': None,
#   'forwardPE': 2210.2563,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 4250,
#   'regularMarketOpen': 4270,
#   'twoHundredDayAverage': 4041.5,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.66620004,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 4330,
#   'navPrice': None,
#   'averageDailyVolume10Day': 161049710,
#   'regularMarketPreviousClose': 4250,
#   'fiftyDayAverage': 4499.8,
#   'trailingAnnualDividendRate': 0,
#   'open': 4270,
#   'toCurrency': None,
#   'averageVolume10days': 161049710,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 168.01,
#   'exDividendDate': 1623196800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 4230,
#   'currency': 'IDR',
#   'trailingPE': 17.171724,
#   'regularMarketVolume': 469620300,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 426958101938176,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 144921317,
#   'dayLow': 4230,
#   'ask': 4310,
#   'askSize': 0,
#   'volume': 469620300,
#   'fiftyTwoWeekHigh': 4850,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.76,
#   'fiftyTwoWeekLow': 3000,
#   'bid': 4300,
#   'tradeable': False,
#   'dividendYield': 0.0395,
#   'bidSize': 0,
#   'dayHigh': 4330,
#   'regularMarketPrice': 4310,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/telkom.co.id'},
#  {'zip': '12190',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 37752,
#   'longBusinessSummary': "PT Bank Mandiri (Persero) Tbk provides various banking products and services to individuals and businesses in Indonesia, Singapore, Hong Kong, Timor Leste, Shanghai, Malaysia, the United Kingdom, and the Cayman Islands. It offers savings and current accounts, time deposits, demand deposits, and foreign currency savings and current accounts; motorcycle loans, mortgage loan, and housing loans, as well as loans for various purposes, such as education, home renovation, marriage, health, and other needs for individuals; and working capital loans, investment loans, people's business loans, syndicated loans, and micro business loans for businesses. The company also provides investment products comprising mutual funds, stocks, and bond trading; life, health, and general insurance products; credit, debit, and corporate cards; e-banking services; digital lending; cash management services; trade finance services, value chain, supply chain management, global and domestic trade, export and import, standby letter of credit, and bank guarantee, as well as spot and forex services; custodial services; treasury services, including cash transaction/liquidity, hedging, and investment products; trust services comprising trustee, paying agent, security agent, escrow agent, monitoring agent, and receiving bank services; and money transfer, remittance services, and venture capital financing. As of 31 December 2021, it operated 2,609 branches, including 137 branch offices, 2,465 sub-branch offices, and 7 overseas branch offices; and 13,087 ATM facilities. The company was founded in 1998 and is headquartered in Jakarta, Indonesia.",
#   'city': 'Jakarta',
#   'phone': '62 21 526 5045',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://bankmandiri.co.id',
#   'maxAge': 1,
#   'address1': 'Plaza Mandiri',
#   'fax': '62 21 527 4477',
#   'industry': 'Banks—Regional',
#   'address2': 'Jl. Jenderal Gatot Subroto Kav. 36-38',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.35059,
#   'grossMargins': 0,
#   'operatingCashflow': 5616078159872,
#   'revenueGrowth': 0.25,
#   'operatingMargins': 0.47230998,
#   'ebitda': None,
#   'targetLowPrice': 7490,
#   'recommendationKey': 'buy',
#   'grossProfits': 84689129000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 9500,
#   'currentPrice': 8500,
#   'earningsGrowth': 0.695,
#   'currentRatio': None,
#   'returnOnAssets': 0.02105,
#   'numberOfAnalystOpinions': 21,
#   'targetMeanPrice': 9565.4,
#   'debtToEquity': None,
#   'returnOnEquity': 0.17,
#   'targetHighPrice': 10600,
#   'totalCash': 129916309864448,
#   'totalDebt': 127936682262528,
#   'totalRevenue': 91678476075008,
#   'totalCashPerShare': 2786.034,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 1966.024,
#   'quickRatio': None,
#   'recommendationMean': 1.6,
#   'exchange': 'JKT',
#   'shortName': 'Bank Mandiri (Persero) Tbk.',
#   'longName': 'PT Bank Mandiri (Persero) Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BMRI.JK',
#   'messageBoardId': 'finmb_8387507',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 4.501,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': 0.34426224,
#   'morningStarRiskRating': None,
#   'forwardEps': 856.3,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 46631301120,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 4184.215,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.28518,
#   'netIncomeToCommon': 32141308067840,
#   'trailingEps': 689.259,
#   'lastDividendValue': 360.6356,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 2.0314445,
#   'heldPercentInsiders': 0.56079,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 17002226139,
#   'beta': 0.833689,
#   'enterpriseValue': 412630661464064,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1505260800,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1647820800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.695,
#   'priceToSalesTrailing12Months': 4.3234363,
#   'dateShortInterest': None,
#   'pegRatio': 0.74,
#   'ytdReturn': None,
#   'forwardPE': 9.926428,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 8200,
#   'regularMarketOpen': 8275,
#   'twoHundredDayAverage': 7189,
#   'trailingAnnualDividendYield': 0.04398,
#   'payoutRatio': 0.5232,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 8500,
#   'navPrice': None,
#   'averageDailyVolume10Day': 69803700,
#   'regularMarketPreviousClose': 8200,
#   'fiftyDayAverage': 7956,
#   'trailingAnnualDividendRate': 360.636,
#   'open': 8275,
#   'toCurrency': None,
#   'averageVolume10days': 69803700,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 360.64,
#   'exDividendDate': 1647820800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 8225,
#   'currency': 'IDR',
#   'trailingPE': 12.332085,
#   'regularMarketVolume': 131027000,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 396366056521728,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 76086201,
#   'dayLow': 8225,
#   'ask': 8500,
#   'askSize': 0,
#   'volume': 131027000,
#   'fiftyTwoWeekHigh': 9075,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 5625,
#   'bid': 8425,
#   'tradeable': False,
#   'dividendYield': 0.044,
#   'bidSize': 0,
#   'dayHigh': 8500,
#   'regularMarketPrice': 8500,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bankmandiri.co.id'},
#  {'zip': '15345',
#   'sector': 'Consumer Defensive',
#   'fullTimeEmployees': 4949,
#   'longBusinessSummary': "PT Unilever Indonesia Tbk manufactures, markets, and distributes consumer goods in Indonesia. It offers soaps, detergents, dairy based foods, ice creams, savories, soy sauce, cosmetic products, tea-based beverages, and fruit juices. The company provides its products under the Axe, Bango, Buavita, Cif, Citra, Clear, Clear Men, Close Up, Cornetto, Dove, Feast, Feast, Glow & Lovely, Hellmann's, Jawara, Knorr, Lifebuoy, Lipton, Love Beauty & Planet, Lux, Magnum, Molto, Paddle Pop, Pepsodent, Pond's, Pond's Men, Populaire, Rexona, Rinso, Royco, SariWangi, Seru, Simple, St. Ives, Suave, Sunlight, Sunsilk, Superpell, TRESemmé, The Vegetarian Butcher, Unilever Professional, Vaseline Men, Viennetta, Vixal, Wall's, Wipol, Zwitsalm, and other brands. It also leases office space. The company was founded in 1933 and is headquartered in Tangerang, Indonesia. PT Unilever Indonesia Tbk is a subsidiary of Unilever Indonesia Holding B.V.",
#   'city': 'Tangerang',
#   'phone': '62 21 8082 7000',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.unilever.co.id',
#   'maxAge': 1,
#   'address1': 'Grha Unilever',
#   'fax': '62 21 8082 7002',
#   'industry': 'Household & Personal Products',
#   'address2': 'Jl. BSD Boulevard Barat Green Office Park Kavling 3 BSD City',
#   'ebitdaMargins': 0.22275,
#   'profitMargins': 0.15165,
#   'grossMargins': 0.48643002,
#   'operatingCashflow': 9075333005312,
#   'revenueGrowth': 0.054,
#   'operatingMargins': 0.20187001,
#   'ebitda': 8932738203648,
#   'targetLowPrice': 2800,
#   'recommendationKey': 'hold',
#   'grossProfits': 19626387000000,
#   'freeCashflow': 7100859678720,
#   'targetMedianPrice': 4110,
#   'currentPrice': 4730,
#   'earningsGrowth': 0.19,
#   'currentRatio': 0.775,
#   'returnOnAssets': 0.24070999,
#   'numberOfAnalystOpinions': 18,
#   'targetMeanPrice': 4187.2,
#   'debtToEquity': 20.125,
#   'returnOnEquity': 0.93964,
#   'targetHighPrice': 6400,
#   'totalCash': 552736980992,
#   'totalDebt': 1284574937088,
#   'totalRevenue': 40101480497152,
#   'totalCashPerShare': 14.489,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 1051.153,
#   'quickRatio': 0.505,
#   'recommendationMean': 2.7,
#   'exchange': 'JKT',
#   'shortName': 'Unilever Indonesia Tbk.',
#   'longName': 'PT Unilever Indonesia Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'UNVR.JK',
#   'messageBoardId': 'finmb_6140557',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 4.442,
#   'beta3Year': None,
#   'enterpriseToEbitda': 19.941,
#   '52WeekChange': -0.2051282,
#   'morningStarRiskRating': None,
#   'forwardEps': 169.8,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 38150000640,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 167.316,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.03121,
#   'netIncomeToCommon': 6081275232256,
#   'trailingEps': 159.404,
#   'lastDividendValue': 66,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 28.269861,
#   'heldPercentInsiders': 0.84995,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 5725552000,
#   'beta': 0.229157,
#   'enterpriseValue': 178129339416576,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1577923200,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1638230400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.19,
#   'priceToSalesTrailing12Months': 4.4998217,
#   'dateShortInterest': None,
#   'pegRatio': 17.75,
#   'ytdReturn': None,
#   'forwardPE': 27.8563,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 4650,
#   'regularMarketOpen': 4680,
#   'twoHundredDayAverage': 4127.375,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 1.044,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 4820,
#   'navPrice': None,
#   'averageDailyVolume10Day': 52349270,
#   'regularMarketPreviousClose': 4650,
#   'fiftyDayAverage': 3913.7,
#   'trailingAnnualDividendRate': 0,
#   'open': 4680,
#   'toCurrency': None,
#   'averageVolume10days': 52349270,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 132,
#   'exDividendDate': 1638230400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 4630,
#   'currency': 'IDR',
#   'trailingPE': 29.67303,
#   'regularMarketVolume': 93943100,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 180449510948864,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 42634607,
#   'dayLow': 4630,
#   'ask': 4750,
#   'askSize': 0,
#   'volume': 93943100,
#   'fiftyTwoWeekHigh': 6000,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.67,
#   'fiftyTwoWeekLow': 3280,
#   'bid': 4730,
#   'tradeable': False,
#   'dividendYield': 0.028399998,
#   'bidSize': 0,
#   'dayHigh': 4820,
#   'regularMarketPrice': 4730,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/unilever.co.id'},
#  {'zip': '10210',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 79115,
#   'longBusinessSummary': 'PT Bank Rakyat Indonesia (Persero) Tbk provides various banking products and services in Indonesia, Singapore, Timor Leste, Hong Kong, Taiwan, Singapore, and the United States. The company offers current and savings accounts; time deposits; house, micro business, working capital, investment, food, warehouse receipt, partnership, franchise, and cash collateral loans; and supply chain financing solutions. It also provides banking services, such as bill payment, deposit, online transaction, money transfer, and remittance services; investment products, such as pension and mutual funds, and retail bonds and retail sukuk products; import and export services; letter of credits; and BRI RTE online system and money changer services. In addition, the company offers Internet banking and merchant services; credit cards; wealth management services; business guarantee and clearing business services; financial and institutional business banking services; and treasury, custodian, trustee, and cash management services. PT Bank Rakyat Indonesia (Persero) Tbk was founded in 1895 and is headquartered in Jakarta, Indonesia.',
#   'city': 'Jakarta',
#   'phone': '62 21 251 0244',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://bri.co.id',
#   'maxAge': 1,
#   'address1': 'Gedung BRI',
#   'fax': '62 21 250 0077',
#   'industry': 'Banks—Regional',
#   'address2': 'Jl. Jenderal Sudirman Kav.44-46',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.33731,
#   'grossMargins': 0,
#   'operatingCashflow': -25941319352320,
#   'revenueGrowth': 0.133,
#   'operatingMargins': 0.3341,
#   'ebitda': None,
#   'targetLowPrice': 4100,
#   'recommendationKey': 'buy',
#   'grossProfits': 110031247000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 5200,
#   'currentPrice': 4630,
#   'earningsGrowth': 0.455,
#   'currentRatio': None,
#   'returnOnAssets': 0.02516,
#   'numberOfAnalystOpinions': 21,
#   'targetMeanPrice': 5176.5,
#   'debtToEquity': None,
#   'returnOnEquity': 0.16364,
#   'targetHighPrice': 6000,
#   'totalCash': 108730502873088,
#   'totalDebt': 135418917945344,
#   'totalRevenue': 115051889426432,
#   'totalCashPerShare': 717.489,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 833.925,
#   'quickRatio': None,
#   'recommendationMean': 2,
#   'exchange': 'JKT',
#   'shortName': 'Bank Rakyat Indonesia (Persero)',
#   'longName': 'PT Bank Rakyat Indonesia (Persero) Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BBRI.JK',
#   'messageBoardId': 'finmb_8391292',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.363,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': 0.039906144,
#   'morningStarRiskRating': None,
#   'forwardEps': 343.59,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 151543005184,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 1796.682,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.23211999,
#   'netIncomeToCommon': 38808334630912,
#   'trailingEps': 280.987,
#   'lastDividendValue': 174.2515,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 2.5769725,
#   'heldPercentInsiders': 0.56134,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 62931290681,
#   'beta': 0.822573,
#   'enterpriseValue': 732044426477568,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1510272000,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1646956800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.782,
#   'priceToSalesTrailing12Months': 6.098501,
#   'dateShortInterest': None,
#   'pegRatio': 0.77,
#   'ytdReturn': None,
#   'forwardPE': 13.475363,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 4430,
#   'regularMarketOpen': 4470,
#   'twoHundredDayAverage': 4231.1562,
#   'trailingAnnualDividendYield': 0.039334312,
#   'payoutRatio': 0.66510004,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 4630,
#   'navPrice': None,
#   'averageDailyVolume10Day': 187791000,
#   'regularMarketPreviousClose': 4430,
#   'fiftyDayAverage': 4611.6,
#   'trailingAnnualDividendRate': 174.251,
#   'open': 4470,
#   'toCurrency': None,
#   'averageVolume10days': 187791000,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 174.25,
#   'exDividendDate': 1646956800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 4450,
#   'currency': 'IDR',
#   'trailingPE': 16.47763,
#   'regularMarketVolume': 379626500,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 701644111085568,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 195128757,
#   'dayLow': 4450,
#   'ask': 4630,
#   'askSize': 0,
#   'volume': 379626500,
#   'fiftyTwoWeekHigh': 4980,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.29,
#   'fiftyTwoWeekLow': 3463.5764,
#   'bid': 4620,
#   'tradeable': False,
#   'dividendYield': 0.039300002,
#   'bidSize': 0,
#   'dayHigh': 4630,
#   'regularMarketPrice': 4630,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bri.co.id'},
#  {'sector': 'Communication Services',
#   'fullTimeEmployees': 1427,
#   'longBusinessSummary': 'PT Sarana Menara Nusantara Tbk. owns and operates telecommunication towers for wireless operators in Indonesia. The company operates in two segments, Tower Rental, and Very Small Aperture Terminal (VSAT) and Wireline Services. It leases space at its multi-tenant tower for wireless operators under long term lease agreements; and provides fiber optic network, as well as offers VSAT solution to facilitate communication access to remote locations. The company was founded in 2008 and is headquartered in Kudus, Indonesia. PT Sarana Menara Nusantara Tbk. is a subsidiary of PT Sapta Adhikari Investama.',
#   'city': 'Kudus',
#   'phone': '62 29 143 1691',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.ptsmn.co.id',
#   'maxAge': 1,
#   'address1': 'Jl. Jend. Ahmad Yani No. 19A',
#   'fax': '62 29 143 1718',
#   'industry': 'Telecom Services',
#   'ebitdaMargins': 0.7288,
#   'profitMargins': 0.3969,
#   'grossMargins': 0.94437,
#   'operatingCashflow': 6196245823488,
#   'revenueGrowth': 0.359,
#   'operatingMargins': 0.62773,
#   'ebitda': 6293418934272,
#   'targetLowPrice': 1075,
#   'recommendationKey': 'buy',
#   'grossProfits': 8154992000000,
#   'freeCashflow': 3389709877248,
#   'targetMedianPrice': 1400,
#   'currentPrice': 1000,
#   'earningsGrowth': -0.082,
#   'currentRatio': 0.338,
#   'returnOnAssets': 0.0677,
#   'numberOfAnalystOpinions': 15,
#   'targetMeanPrice': 1492.3,
#   'debtToEquity': 390.67,
#   'returnOnEquity': 0.30998,
#   'targetHighPrice': 2075,
#   'totalCash': 4748364218368,
#   'totalDebt': 47122644729856,
#   'totalRevenue': 8635345797120,
#   'totalCashPerShare': 95.351,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 173.316,
#   'quickRatio': 0.317,
#   'recommendationMean': 1.9,
#   'exchange': 'JKT',
#   'shortName': 'Sarana Menara Nusantara Tbk.',
#   'longName': 'PT Sarana Menara Nusantara Tbk.',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'TOWR.JK',
#   'messageBoardId': 'finmb_99201025',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 10.476,
#   'beta3Year': None,
#   'enterpriseToEbitda': 14.374,
#   '52WeekChange': -0.19917011,
#   'morningStarRiskRating': None,
#   'forwardEps': 76.89,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 49798901760,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 241.591,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.21653,
#   'netIncomeToCommon': 3427374989312,
#   'trailingEps': 68.789,
#   'lastDividendValue': 6,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 4.139227,
#   'heldPercentInsiders': 0.5857,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1640908800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 21664530771,
#   'beta': 0.595553,
#   'enterpriseValue': 90461280665600,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1530144000,
#   'lastSplitFactor': '5:1',
#   'legalType': None,
#   'lastDividendDate': 1639612800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.086,
#   'priceToSalesTrailing12Months': 5.766868,
#   'dateShortInterest': None,
#   'pegRatio': 1.51,
#   'ytdReturn': None,
#   'forwardPE': 13.005592,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 965,
#   'regularMarketOpen': 965,
#   'twoHundredDayAverage': 1136.025,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.4071,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 1000,
#   'navPrice': None,
#   'averageDailyVolume10Day': 44913610,
#   'regularMarketPreviousClose': 965,
#   'fiftyDayAverage': 1016.1,
#   'trailingAnnualDividendRate': 0,
#   'open': 965,
#   'toCurrency': None,
#   'averageVolume10days': 44913610,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 28.09,
#   'exDividendDate': 1639612800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 955,
#   'currency': 'IDR',
#   'trailingPE': 14.537208,
#   'regularMarketVolume': 134740900,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 49798900088832,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 52982080,
#   'dayLow': 955,
#   'ask': 1000,
#   'askSize': 0,
#   'volume': 134740900,
#   'fiftyTwoWeekHigh': 1625,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 930,
#   'bid': 995,
#   'tradeable': False,
#   'dividendYield': 0.0291,
#   'bidSize': 0,
#   'dayHigh': 1000,
#   'regularMarketPrice': 1000,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/ptsmn.co.id'},
#  {'zip': '13910',
#   'sector': 'Basic Materials',
#   'fullTimeEmployees': 29118,
#   'longBusinessSummary': 'PT United Tractors Tbk, together with its subsidiaries, sells and rents heavy equipment in Indonesia. The company operates through five segments: Construction Machinery, Mining Contracting, Coal Mining, Gold Mining, and Construction Industry. The company distributes heavy equipment and spare-parts under the Komatsu, UD Trucks, Scania, Bomag, and Tadano names to mining, plantation, construction, and forestry sectors, as well as for transportation; and offers services in the areas of non-destructive test, full maintenance contract, UT PAP service, machine inspection program, service call, workshop service, tire management system, pit stop management service, fabrication and remanufacturing cylinder, and UT remanufacturing. It also transports coal through river; and distributes tractors, generators, forklifts, and mini excavators, as well as sells commodity parts, as well as operates mini hydro power plant located in Banjarnegara, Central Java. In addition, the company offers mining services that supports coal companies, such as mining design and implementation, preliminary assessment and feasibility studies, construction of infrastructure and plant, removal of overburden and waste, commercial exploitation, expansion of mine/plant, reclamation and revegetation, and transshipment and marketing, as well as owns interests in various coal mine concessions with total estimated coal reserves of 395 million tons. Further, it engages in the engineering, planning, assembling, and manufacturing components of machinery, tools, parts, and heavy equipment; provision of vessel construction and related repair services; provision of vessel charter and shipping services; construction and concrete product businesses; operating power plants; gold mining business; and fishery business. The company was founded in 1972 and is based in Jakarta Timur, Indonesia. PT United Tractors Tbk is a subsidiary of PT Astra International Tbk.',
#   'city': 'Jakarta Timur',
#   'phone': '62 21 2457 9999',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.unitedtractors.com',
#   'maxAge': 1,
#   'address1': 'Jl. Raya Bekasi Km 22',
#   'fax': '62 21 460 0657',
#   'industry': 'Other Industrial Metals & Mining',
#   'address2': 'Cakung',
#   'ebitdaMargins': 0.28524,
#   'profitMargins': 0.14220999,
#   'grossMargins': 0.25872,
#   'operatingCashflow': None,
#   'revenueGrowth': 0.563,
#   'operatingMargins': 0.19965,
#   'ebitda': 25540809457664,
#   'targetLowPrice': 25100,
#   'recommendationKey': 'buy',
#   'grossProfits': 19664961000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 33000,
#   'currentPrice': 30400,
#   'earningsGrowth': 1.316,
#   'currentRatio': 2.035,
#   'returnOnAssets': 0.099139996,
#   'numberOfAnalystOpinions': 17,
#   'targetMeanPrice': 32742.9,
#   'debtToEquity': 8.259,
#   'returnOnEquity': 0.18572001,
#   'targetHighPrice': 41000,
#   'totalCash': 35716436328448,
#   'totalDebt': 6369434927104,
#   'totalRevenue': 89541713068032,
#   'totalCashPerShare': 9575.106,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 24008.709,
#   'quickRatio': 1.612,
#   'recommendationMean': 1.8,
#   'exchange': 'JKT',
#   'shortName': 'United Tractors Tbk.',
#   'longName': 'PT United Tractors Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': True,
#   'gmtOffSetMilliseconds': '25200000',
#   'underlyingSymbol': None,
#   'quoteType': 'EQUITY',
#   'symbol': 'UNTR.JK',
#   'underlyingExchangeSymbol': None,
#   'headSymbol': None,
#   'messageBoardId': 'finmb_877021',
#   'uuid': '9a8eb48e-0160-3c46-b8f3-ab5a2544a681',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.974,
#   'beta3Year': None,
#   'enterpriseToEbitda': 3.414,
#   '52WeekChange': None,
#   'morningStarRiskRating': None,
#   'forwardEps': 3152.46,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 3730139904,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 17723.48,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.13423,
#   'netIncomeToCommon': 12733688840192,
#   'trailingEps': 2273.955,
#   'lastDividendValue': None,
#   'SandP52WeekChange': None,
#   'priceToBook': 1.7152387,
#   'heldPercentInsiders': 0.595,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 1510704730,
#   'beta': 0.617399,
#   'enterpriseValue': 87193070600192,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': None,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 1.315,
#   'priceToSalesTrailing12Months': 1.266407,
#   'dateShortInterest': None,
#   'pegRatio': 0.27,
#   'ytdReturn': None,
#   'forwardPE': 9.643263,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 29975,
#   'regularMarketOpen': 29725,
#   'twoHundredDayAverage': 24057.375,
#   'trailingAnnualDividendYield': 0.026955796,
#   'payoutRatio': 0.2367,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 30500,
#   'navPrice': None,
#   'averageDailyVolume10Day': 5329960,
#   'regularMarketPreviousClose': 29975,
#   'fiftyDayAverage': 28079.5,
#   'trailingAnnualDividendRate': 808,
#   'open': 29725,
#   'averageVolume10days': 5329960,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1240,
#   'exDividendDate': 1650412800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 29700,
#   'currency': 'IDR',
#   'trailingPE': 13.368777,
#   'regularMarketVolume': 4926800,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 113396255031296,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 6007992,
#   'dayLow': 29700,
#   'ask': 30125,
#   'askSize': 0,
#   'volume': 4926800,
#   'fiftyTwoWeekHigh': 31875,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 18525,
#   'bid': 29900,
#   'tradeable': False,
#   'dividendYield': 0.0423,
#   'bidSize': 0,
#   'dayHigh': 30500,
#   'regularMarketPrice': 30400,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/unitedtractors.com'},
#  {'zip': '12910',
#   'sector': 'Consumer Defensive',
#   'fullTimeEmployees': 90339,
#   'longBusinessSummary': 'PT Indofood Sukses Makmur Tbk produces and sells various food products in Indonesia and internationally. It operates through four segments: Consumer Branded Products Business Group, Bogasari Business Group, Agribusiness Group, and Distribution Business Group. The Consumer Branded Products Business Group segment offers noodles; dairy products, including sweetened condensed, temperature, sterilized bottled, pasteurized liquid, multi-cereal, and powdered milk, as well as butter, ice cream, and creamer; snack foods, such as potato, cassava, soybean, sweet potato, corn, and various extruded snacks, as well as biscuits; culinary products and syrups; nutrition and special foods; and ready-to-drink tea, packaged water, and fruit-flavored drinks. The Bogasari Business Group segment produces flour and pasta. The Agribusiness Group segment produces palm oil, rubber, sugar cane, timber, cocoa, and tea; and manufactures and markets cooking oils, margarines, shortenings, and other by-products. The Distribution Business Group segment distributes third-party products. It is also involved in the shipping, investment, trade export agency, industrial estate, and restaurant chain management activities; ownership and management of buildings; and provision of management consulting, flour blending and trading, and research management and technical services, as well as packaging materials and fertilizers. In addition, it manufactures coffee; extracts and processes coconut oil; operates bulking station; provides transportation services; and markets and distributes paper diapers and packaged drinking water. The company was formerly known as PT Panganjaya Intikusuma and changed its name to PT Indofood Sukses Makmur Tbk in 1994. The company was incorporated in 1990 and is headquartered in Jakarta, Indonesia. PT Indofood Sukses Makmur Tbk is a subsidiary of First Pacific Investment Management Limited.',
#   'city': 'Jakarta',
#   'phone': '62 21 5795 8822',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.indofood.com',
#   'maxAge': 1,
#   'address1': 'Sudirman Plaza',
#   'fax': '62 21 5793 5960',
#   'industry': 'Packaged Foods',
#   'address2': 'Indofood Tower 27th Floor Jl. Jend. Sudirman Kav. 76-78',
#   'ebitdaMargins': 0.21029,
#   'profitMargins': 0.07692,
#   'grossMargins': 0.32791,
#   'operatingCashflow': 14692640620544,
#   'revenueGrowth': 0.156,
#   'operatingMargins': 0.17525,
#   'ebitda': 20891454930944,
#   'targetLowPrice': 5900,
#   'recommendationKey': 'buy',
#   'grossProfits': 32576751000000,
#   'freeCashflow': 15564480184320,
#   'targetMedianPrice': 7800,
#   'currentPrice': 6600,
#   'earningsGrowth': -0.174,
#   'currentRatio': 1.341,
#   'returnOnAssets': 0.063540004,
#   'numberOfAnalystOpinions': 13,
#   'targetMeanPrice': 7822.3,
#   'debtToEquity': 72.317,
#   'returnOnEquity': 0.13517,
#   'targetHighPrice': 9300,
#   'totalCash': 30631763378176,
#   'totalDebt': 62649479987200,
#   'totalRevenue': 99345621843968,
#   'totalCashPerShare': 3488.642,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 11314.441,
#   'quickRatio': 0.965,
#   'recommendationMean': 1.7,
#   'exchange': 'JKT',
#   'shortName': 'Indofood Sukses Makmur Tbk.',
#   'longName': 'PT Indofood Sukses Makmur Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'INDF.JK',
#   'messageBoardId': 'finmb_879610',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.279,
#   'beta3Year': None,
#   'enterpriseToEbitda': 6.08,
#   '52WeekChange': 0,
#   'morningStarRiskRating': None,
#   'forwardEps': 965.4,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 8780430336,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 5496.855,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.09708,
#   'netIncomeToCommon': 7642197000192,
#   'trailingEps': 870.367,
#   'lastDividendValue': 278,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 1.2006866,
#   'heldPercentInsiders': 0.50083,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1640908800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 4382925496,
#   'beta': 0.209918,
#   'enterpriseValue': 127018851106816,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': None,
#   'lastDividendDate': 1630972800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.174,
#   'priceToSalesTrailing12Months': 0.58332556,
#   'dateShortInterest': None,
#   'pegRatio': 1.64,
#   'ytdReturn': None,
#   'forwardPE': 6.836544,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 6450,
#   'regularMarketOpen': 6450,
#   'twoHundredDayAverage': 6324.75,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.3195,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 6600,
#   'navPrice': None,
#   'averageDailyVolume10Day': 9781220,
#   'regularMarketPreviousClose': 6450,
#   'fiftyDayAverage': 6189,
#   'trailingAnnualDividendRate': 0,
#   'open': 6450,
#   'toCurrency': None,
#   'averageVolume10days': 9781220,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 278,
#   'exDividendDate': 1630972800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 6400,
#   'currency': 'IDR',
#   'trailingPE': 7.583008,
#   'regularMarketVolume': 20679300,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 57950840291328,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 11431696,
#   'dayLow': 6400,
#   'ask': 6600,
#   'askSize': 0,
#   'volume': 20679300,
#   'fiftyTwoWeekHigh': 6950,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.66,
#   'fiftyTwoWeekLow': 5725,
#   'bid': 6575,
#   'tradeable': False,
#   'dividendYield': 0.0431,
#   'bidSize': 0,
#   'dayHigh': 6600,
#   'regularMarketPrice': 6600,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/indofood.com'},
#  {'zip': '10220',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 26502,
#   'longBusinessSummary': 'PT Bank Negara Indonesia (Persero) Tbk, together with its subsidiaries, provides various banking products and services in Indonesia, the United States, Europe, and Asia. The company offers current, savings, and money market accounts, and time deposit products. It also provides credit facilities for the purchase of houses, villas, apartments, condominiums, home shops, home offices, and land plots, as well as for construction/renovation, top-up, and refinancing; and pension loans. In addition, the company offers debit and credit cards; SMS, Internet, and phone banking services, as well as automated teller machines; treasury services; transactional banking products, such as payment, collection, liquidity, and information management services; small and long-term loans, which include working capital credit, investment credit, bank guarantee, local letter of credit, and letter of credit; and customer analysis and portfolio management services. Further, it provides facilities for foreign exchange services; investment products, such as government, retail, and company bonds; transaction derivatives; BNIFX, a web-based digital platform to conduct non-physical forex transactions directly with BNI treasury dealers; local currency settlement; and trade finance services, which include export and import LC and non-LC, standby letter of credit, bill collection financing, open account financing, and BNI Trade Online, a digital service to submit requests for trade transactions online. The company serves agriculture, telecommunication, food and beverage, oil and gas, mining, chemicals, construction, electricity, and wholesale and retail. As of December 31, 2021, the company operated 195 domestic branches, 1,097 sub-branches, and 874 other outlets, as well as 5 overseas branches located in Singapore, Hong Kong, Tokyo, London, and Seoul; and 1 representative office in New York. PT Bank Negara Indonesia (Persero) Tbk was founded in 1946 and is headquartered in Jakarta Pusat, Indonesia.',
#   'city': 'Jakarta Pusat',
#   'phone': '62 21 251 1946',
#   'country': 'Indonesia',
#   'companyOfficers': [],
#   'website': 'https://www.bni.co.id',
#   'maxAge': 1,
#   'address1': 'Gedung Grha BNI',
#   'fax': '62 21 251 1961',
#   'industry': 'Banks—Regional',
#   'address2': 'Jl. Jenderal Sudirman Kav. 1',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.33832002,
#   'grossMargins': 0,
#   'operatingCashflow': -32999269728256,
#   'revenueGrowth': 0.234,
#   'operatingMargins': 0.34864,
#   'ebitda': None,
#   'targetLowPrice': 8250,
#   'recommendationKey': 'buy',
#   'grossProfits': 34371327000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 9700,
#   'currentPrice': 9175,
#   'earningsGrowth': 0.664,
#   'currentRatio': None,
#   'returnOnAssets': 0.0139999995,
#   'numberOfAnalystOpinions': 21,
#   'targetMeanPrice': 9826.5,
#   'debtToEquity': None,
#   'returnOnEquity': 0.10198,
#   'targetHighPrice': 13000,
#   'totalCash': 112886479323136,
#   'totalDebt': 51005144170496,
#   'totalRevenue': 36876459180032,
#   'totalCashPerShare': 6061.353,
#   'financialCurrency': 'IDR',
#   'revenuePerShare': 1981.116,
#   'quickRatio': None,
#   'recommendationMean': 1.8,
#   'exchange': 'JKT',
#   'shortName': 'Bank Negara Indonesia (Persero)',
#   'longName': 'PT Bank Negara Indonesia (Persero) Tbk',
#   'exchangeTimezoneName': 'Asia/Jakarta',
#   'exchangeTimezoneShortName': 'WIB',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '25200000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BBNI.JK',
#   'messageBoardId': 'finmb_882643',
#   'market': 'id_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 3.029,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': 0.6576576,
#   'morningStarRiskRating': None,
#   'forwardEps': 1054.13,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 24682600,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 6756.596,
#   'sharesShort': None,
#   'sharesPercentSharesOut': None,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.14423999,
#   'netIncomeToCommon': 12476080979968,
#   'trailingEps': 670.253,
#   'lastDividendValue': 146.2969,
#   'SandP52WeekChange': -0.010423481,
#   'priceToBook': 1.3579322,
#   'heldPercentInsiders': 0.68162,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1648684800,
#   'shortRatio': None,
#   'sharesShortPreviousMonthDate': None,
#   'floatShares': 5754807922,
#   'beta': 1.230867,
#   'enterpriseValue': 111698845368320,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': None,
#   'lastSplitFactor': None,
#   'legalType': None,
#   'lastDividendDate': 1648080000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.662,
#   'priceToSalesTrailing12Months': 4.652505,
#   'dateShortInterest': None,
#   'pegRatio': 0.14,
#   'ytdReturn': None,
#   'forwardPE': 8.70386,
#   'lastCapGain': None,
#   'shortPercentOfFloat': None,
#   'sharesShortPriorMonth': None,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 9200,
#   'regularMarketOpen': 9275,
#   'twoHundredDayAverage': 7190.25,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0.2841,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 9350,
#   'navPrice': None,
#   'averageDailyVolume10Day': 40905400,
#   'regularMarketPreviousClose': 9200,
#   'fiftyDayAverage': 8694.5,
#   'trailingAnnualDividendRate': 0,
#   'open': 9275,
#   'toCurrency': None,
#   'averageVolume10days': 40905400,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 146.3,
#   'exDividendDate': 1648080000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 9075,
#   'currency': 'IDR',
#   'trailingPE': 13.688861,
#   'regularMarketVolume': 86679100,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 171567904456704,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 41142392,
#   'dayLow': 9075,
#   'ask': 9200,
#   'askSize': 0,
#   'volume': 86679100,
#   'fiftyTwoWeekHigh': 9900,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.7,
#   'fiftyTwoWeekLow': 4560,
#   'bid': 9175,
#   'tradeable': False,
#   'dividendYield': 0.0159,
#   'bidSize': 0,
#   'dayHigh': 9350,
#   'regularMarketPrice': 9175,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/bni.co.id'}]

# %%
fundamentals = ['revenueGrowth','pegRatio', 'bookValue', 'profitMargins', 'returnOnAssets', 'dividendYield', 'marketCap', 'beta', 'forwardPE']

# %%
df = pd.DataFrame(infos)
df
# Out:
#      zip                  sector  fullTimeEmployees  \
# 0  10310      Financial Services              25066
# 1  10220       Consumer Cyclical             124879
# 2  40133  Communication Services              21099
# 3  12190      Financial Services              37752
# 4  15345      Consumer Defensive               4949
# 5  10210      Financial Services              79115
# 6    NaN  Communication Services               1427
# 7  13910         Basic Materials              29118
# 8  12910      Consumer Defensive              90339
# 9  10220      Financial Services              26502
#
#                                  longBusinessSummary           city  \
# 0  PT Bank Central Asia Tbk, together with its su...        Jakarta
# 1  PT Astra International Tbk, together with its ...        Jakarta
# 2  Perusahaan Perseroan (Persero) PT Telekomunika...        Bandung
# 3  PT Bank Mandiri (Persero) Tbk provides various...        Jakarta
# 4  PT Unilever Indonesia Tbk manufactures, market...      Tangerang
# 5  PT Bank Rakyat Indonesia (Persero) Tbk provide...        Jakarta
# 6  PT Sarana Menara Nusantara Tbk. owns and opera...          Kudus
# 7  PT United Tractors Tbk, together with its subs...  Jakarta Timur
# 8  PT Indofood Sukses Makmur Tbk produces and sel...        Jakarta
# 9  PT Bank Negara Indonesia (Persero) Tbk, togeth...  Jakarta Pusat
#
#              phone    country companyOfficers                         website  \
# 0  62 21 2358 8000  Indonesia              []           https://www.bca.co.id
# 1  62 21 5084 3888  Indonesia              []         https://www.astra.co.id
# 2   62 22 452 1404  Indonesia              []        https://www.telkom.co.id
# 3   62 21 526 5045  Indonesia              []       https://bankmandiri.co.id
# 4  62 21 8082 7000  Indonesia              []      https://www.unilever.co.id
# 5   62 21 251 0244  Indonesia              []               https://bri.co.id
# 6   62 29 143 1691  Indonesia              []         https://www.ptsmn.co.id
# 7  62 21 2457 9999  Indonesia              []  https://www.unitedtractors.com
# 8  62 21 5795 8822  Indonesia              []        https://www.indofood.com
# 9   62 21 251 1946  Indonesia              []           https://www.bni.co.id
#
#    maxAge  ... dividendYield bidSize dayHigh regularMarketPrice  \
# 0       1  ...        0.0187       0    7750               7750
# 1       1  ...        0.0325       0    7475               7350
# 2       1  ...        0.0395       0    4330               4310
# 3       1  ...        0.0440       0    8500               8500
# 4       1  ...        0.0284       0    4820               4730
# 5       1  ...        0.0393       0    4630               4630
# 6       1  ...        0.0291       0    1000               1000
# 7       1  ...        0.0423       0   30500              30400
# 8       1  ...        0.0431       0    6600               6600
# 9       1  ...        0.0159       0    9350               9175
#
#    preMarketPrice                                      logo_url  \
# 0            None           https://logo.clearbit.com/bca.co.id
# 1            None         https://logo.clearbit.com/astra.co.id
# 2            None        https://logo.clearbit.com/telkom.co.id
# 3            None   https://logo.clearbit.com/bankmandiri.co.id
# 4            None      https://logo.clearbit.com/unilever.co.id
# 5            None           https://logo.clearbit.com/bri.co.id
# 6            None         https://logo.clearbit.com/ptsmn.co.id
# 7            None  https://logo.clearbit.com/unitedtractors.com
# 8            None        https://logo.clearbit.com/indofood.com
# 9            None           https://logo.clearbit.com/bni.co.id
#
#    underlyingSymbol  underlyingExchangeSymbol  headSymbol  \
# 0               NaN                       NaN         NaN
# 1               NaN                       NaN         NaN
# 2               NaN                       NaN         NaN
# 3               NaN                       NaN         NaN
# 4               NaN                       NaN         NaN
# 5               NaN                       NaN         NaN
# 6               NaN                       NaN         NaN
# 7               NaN                       NaN         NaN
# 8               NaN                       NaN         NaN
# 9               NaN                       NaN         NaN
#
#                                    uuid
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7  9a8eb48e-0160-3c46-b8f3-ab5a2544a681
# 8                                   NaN
# 9                                   NaN
#
# [10 rows x 157 columns]

# %%
df = df.set_index('symbol')
df
# Out:
#            zip                  sector  fullTimeEmployees  \
# symbol
# BBCA.JK  10310      Financial Services              25066
# ASII.JK  10220       Consumer Cyclical             124879
# TLKM.JK  40133  Communication Services              21099
# BMRI.JK  12190      Financial Services              37752
# UNVR.JK  15345      Consumer Defensive               4949
# BBRI.JK  10210      Financial Services              79115
# TOWR.JK    NaN  Communication Services               1427
# UNTR.JK  13910         Basic Materials              29118
# INDF.JK  12910      Consumer Defensive              90339
# BBNI.JK  10220      Financial Services              26502
#
#                                        longBusinessSummary           city  \
# symbol
# BBCA.JK  PT Bank Central Asia Tbk, together with its su...        Jakarta
# ASII.JK  PT Astra International Tbk, together with its ...        Jakarta
# TLKM.JK  Perusahaan Perseroan (Persero) PT Telekomunika...        Bandung
# BMRI.JK  PT Bank Mandiri (Persero) Tbk provides various...        Jakarta
# UNVR.JK  PT Unilever Indonesia Tbk manufactures, market...      Tangerang
# BBRI.JK  PT Bank Rakyat Indonesia (Persero) Tbk provide...        Jakarta
# TOWR.JK  PT Sarana Menara Nusantara Tbk. owns and opera...          Kudus
# UNTR.JK  PT United Tractors Tbk, together with its subs...  Jakarta Timur
# INDF.JK  PT Indofood Sukses Makmur Tbk produces and sel...        Jakarta
# BBNI.JK  PT Bank Negara Indonesia (Persero) Tbk, togeth...  Jakarta Pusat
#
#                    phone    country companyOfficers  \
# symbol
# BBCA.JK  62 21 2358 8000  Indonesia              []
# ASII.JK  62 21 5084 3888  Indonesia              []
# TLKM.JK   62 22 452 1404  Indonesia              []
# BMRI.JK   62 21 526 5045  Indonesia              []
# UNVR.JK  62 21 8082 7000  Indonesia              []
# BBRI.JK   62 21 251 0244  Indonesia              []
# TOWR.JK   62 29 143 1691  Indonesia              []
# UNTR.JK  62 21 2457 9999  Indonesia              []
# INDF.JK  62 21 5795 8822  Indonesia              []
# BBNI.JK   62 21 251 1946  Indonesia              []
#
#                                 website  maxAge  ... dividendYield bidSize  \
# symbol                                           ...
# BBCA.JK           https://www.bca.co.id       1  ...        0.0187       0
# ASII.JK         https://www.astra.co.id       1  ...        0.0325       0
# TLKM.JK        https://www.telkom.co.id       1  ...        0.0395       0
# BMRI.JK       https://bankmandiri.co.id       1  ...        0.0440       0
# UNVR.JK      https://www.unilever.co.id       1  ...        0.0284       0
# BBRI.JK               https://bri.co.id       1  ...        0.0393       0
# TOWR.JK         https://www.ptsmn.co.id       1  ...        0.0291       0
# UNTR.JK  https://www.unitedtractors.com       1  ...        0.0423       0
# INDF.JK        https://www.indofood.com       1  ...        0.0431       0
# BBNI.JK           https://www.bni.co.id       1  ...        0.0159       0
#
#         dayHigh regularMarketPrice  preMarketPrice  \
# symbol
# BBCA.JK    7750               7750            None
# ASII.JK    7475               7350            None
# TLKM.JK    4330               4310            None
# BMRI.JK    8500               8500            None
# UNVR.JK    4820               4730            None
# BBRI.JK    4630               4630            None
# TOWR.JK    1000               1000            None
# UNTR.JK   30500              30400            None
# INDF.JK    6600               6600            None
# BBNI.JK    9350               9175            None
#
#                                              logo_url  underlyingSymbol  \
# symbol
# BBCA.JK           https://logo.clearbit.com/bca.co.id               NaN
# ASII.JK         https://logo.clearbit.com/astra.co.id               NaN
# TLKM.JK        https://logo.clearbit.com/telkom.co.id               NaN
# BMRI.JK   https://logo.clearbit.com/bankmandiri.co.id               NaN
# UNVR.JK      https://logo.clearbit.com/unilever.co.id               NaN
# BBRI.JK           https://logo.clearbit.com/bri.co.id               NaN
# TOWR.JK         https://logo.clearbit.com/ptsmn.co.id               NaN
# UNTR.JK  https://logo.clearbit.com/unitedtractors.com               NaN
# INDF.JK        https://logo.clearbit.com/indofood.com               NaN
# BBNI.JK           https://logo.clearbit.com/bni.co.id               NaN
#
#          underlyingExchangeSymbol  headSymbol  \
# symbol
# BBCA.JK                       NaN         NaN
# ASII.JK                       NaN         NaN
# TLKM.JK                       NaN         NaN
# BMRI.JK                       NaN         NaN
# UNVR.JK                       NaN         NaN
# BBRI.JK                       NaN         NaN
# TOWR.JK                       NaN         NaN
# UNTR.JK                       NaN         NaN
# INDF.JK                       NaN         NaN
# BBNI.JK                       NaN         NaN
#
#                                          uuid
# symbol
# BBCA.JK                                   NaN
# ASII.JK                                   NaN
# TLKM.JK                                   NaN
# BMRI.JK                                   NaN
# UNVR.JK                                   NaN
# BBRI.JK                                   NaN
# TOWR.JK                                   NaN
# UNTR.JK  9a8eb48e-0160-3c46-b8f3-ab5a2544a681
# INDF.JK                                   NaN
# BBNI.JK                                   NaN
#
# [10 rows x 156 columns]

# %%
fundamental = df[df.columns[df.columns.isin(fundamentals)]]
fundamental
# Out:
#          profitMargins  revenueGrowth  returnOnAssets  bookValue      beta  \
# symbol
# BBCA.JK        0.45747          0.112         0.02763   1579.308  0.551090
# ASII.JK        0.09196          0.390         0.05374   4427.403  0.648567
# TLKM.JK        0.17210          0.037         0.10245   1290.038  0.195382
# BMRI.JK        0.35059          0.250         0.02105   4184.215  0.833689
# UNVR.JK        0.15165          0.054         0.24071    167.316  0.229157
# BBRI.JK        0.33731          0.133         0.02516   1796.682  0.822573
# TOWR.JK        0.39690          0.359         0.06770    241.591  0.595553
# UNTR.JK        0.14221          0.563         0.09914  17723.480  0.617399
# INDF.JK        0.07692          0.156         0.06354   5496.855  0.209918
# BBNI.JK        0.33832          0.234         0.01400   6756.596  1.230867
#
#          pegRatio    forwardPE        marketCap  dividendYield
# symbol
# BBCA.JK      1.65    22.813578  955381249474560         0.0187
# ASII.JK      1.02    11.092331  297554461851648         0.0325
# TLKM.JK  33640.20  2210.256300  426958101938176         0.0395
# BMRI.JK      0.74     9.926428  396366056521728         0.0440
# UNVR.JK     17.75    27.856300  180449510948864         0.0284
# BBRI.JK      0.77    13.475363  701644111085568         0.0393
# TOWR.JK      1.51    13.005592   49798900088832         0.0291
# UNTR.JK      0.27     9.643263  113396255031296         0.0423
# INDF.JK      1.64     6.836544   57950840291328         0.0431
# BBNI.JK      0.14     8.703860  171567904456704         0.0159

# %% [markdown]
# ## Market Cap
# sebuah ukuran yang didasarkan pada nilai agregat suatu perusahaan. Market cap didapatkan dari total pengalian jumlah outstanding shares (saham) perusahaan yang beredar dengan harga satu lembar saham di pasaran.

# %%
cap = df.sort_values('marketCap', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(cap['shortName'],cap['marketCap'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Profit Margin
# Rasio ini menunjukan keuntungan dengan total penjualan yang di peroleh dari setiap penjualan.

# %%
prof = df.sort_values('profitMargins', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(prof['shortName'],prof['profitMargins'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Revenue Growth
# Pertumbuhan pendapatan mengacu pada peningkatan pendapatan selama periode waktu tertentu. Pertumbuhan pendapatan ini merupakan tingkat kenaikan total pendapatan dibagi dengan total pendapatan dari periode yang sama tahun sebelumnya

# %%
rg = df.sort_values('revenueGrowth', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(rg['shortName'],rg['revenueGrowth'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Pertumbuhan paling baik dimiliki oleh United Tractors

# %% [markdown]
# ## PEG Ratio
# Semakin rendah PEG Ratio suatu perusahaan maka berarti harga sahamnya adalah dibawah harga semestinya ( undervalued) dan perusahaan memiliki rasio pertumbuhan EPS yang tinggi.PEG Ratio yang lebih rendah umumnya merupakan indikator yang lebih baik dalam posisi beli saham

# %%
peg = df.sort_values('pegRatio', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(peg['shortName'],peg['pegRatio'])
plt.xticks(rotation=90)
plt.show()

# %%
fundamental['pegRatio'].sort_values()
# Out:
# symbol
# BBNI.JK        0.14
# UNTR.JK        0.27
# BMRI.JK        0.74
# BBRI.JK        0.77
# ASII.JK        1.02
# TOWR.JK        1.51
# INDF.JK        1.64
# BBCA.JK        1.65
# UNVR.JK       17.75
# TLKM.JK    33640.20
# Name: pegRatio, dtype: float64

# %% [markdown]
# ## Book Value
# Nilai buku adalah nilai total harga saham yang akan tersisa jika perusahaan bangkrut. Dengan kata lain, inilah yang secara teoritis akan diterima pemegang saham jika perusahaan melikuidasi semua asetnya setelah melunasi semua kewajibannya.

# %%
bv = df.sort_values('bookValue', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(bv['shortName'],bv['bookValue'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Return On Assets (ROA)
# Rasio profitabilitas yang menunjukkan kemampuan perusahaan untuk menghasilkan laba dari aktiva yang dipergunakan

# %%
roa = df.sort_values('returnOnAssets', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(roa['shortName'],roa['returnOnAssets'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Beta
# Beta saham adalah indikator untuk mengukur sensitivitas suatu saham terhadap pergerakan pasar secara keseluruhan atau Indeks Harga Saham Gabungan (IHSG). Beta ini bukan hanya untuk mengukur pergerakan harga pada saham saja, akan tetapi beta juga digunakan pada instrumen investasi reksadana.

# %%
beta = df.sort_values('beta', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(beta['shortName'],beta['beta'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 1. Saham Beta Kurang dari 1
#
# Perusahaan yang memiliki beta kurang dari satu, maka sensitivitas harga saham lebih kecil dari IHSG. Suatu saham memiliki angka beta 0,5 dan IHSGnya naik 1%, maka saham tersebut diperkirakan akan naik 0,5% saja. Sebaliknya, jika IHSG turun 2%, harga saham juga ikut turun 1%.
#
# 2. Saham Beta Diatas 1
#
# Saham yang angka beta diatas satu, memiliki volatilitas harga di atas pasar. Contohnya, saham dengan nilai beta 1,5 dan IHSG pada saat itu naik 4%, maka harga saham meningkat 6%.
#
# 3. Beta Saham Negatif
#
# Saham perusahaan juga ada yang memiliki angkat betanya negative (minus). Perusahaan dengan beta dibawah nol ini memiliki kebalikan dari jenis saham lainnya. Apabila IHSG melandai, artinya saham justru akan mengalami kenaikan.

# %% [markdown]
# ## Forward P/E
# Perkiaraan P/E  menggambarkan optimisme pasar terhadap prospek pertumbuhan perusahaan. Perusahaan dengan Forward P/E yang lebih tinggi daripada rata-rata industri atau pasar menunjukkan ekspektasi bahwa perusahaan kemungkinan akan mengalami pertumbuhan yang signifikan.

# %%
fpe = df.sort_values('forwardPE', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(fpe['shortName'],fpe['forwardPE'])
plt.xticks(rotation=90)
plt.show()

# %%
fundamental['forwardPE'].sort_values()
# Out:
# symbol
# INDF.JK       6.836544
# BBNI.JK       8.703860
# UNTR.JK       9.643263
# BMRI.JK       9.926428
# ASII.JK      11.092331
# TOWR.JK      13.005592
# BBRI.JK      13.475363
# BBCA.JK      22.813578
# UNVR.JK      27.856300
# TLKM.JK    2210.256300
# Name: forwardPE, dtype: float64

# %% [markdown]
# ## Dividend Yield
# Dividend yield adalah tingkat pengembalian dalam bentuk dividen tunai kepada pemegang saham.
# Dividend yield dinyatakan dalam persentase. Suatu perusahaan dikatakan memiliki dividend yield tinggi jika di atas 5%. Biasanya investor senang kalau ada yang menawarkan dividend yield tinggi.

# %%
dvy = df.sort_values('dividendYield', ascending=False)
plt.figure(figsize=(14,5))
plt.bar(dvy['shortName'],dvy['dividendYield'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ###

# %%
divs = []

for i in tickers:
    inst = yf.Ticker(i)
    inst.history(period='5y')
    divs.append(inst.dividends)

# %%
divs
# Out:
# [Date
#  2017-11-29     16.0
#  2018-04-13     35.0
#  2018-12-03     17.0
#  2019-04-24     51.0
#  2019-12-06     20.0
#  2020-04-21     91.0
#  2020-12-09     19.6
#  2021-04-08     86.4
#  2021-11-17     25.0
#  2022-03-28    120.0
#  Name: Dividends, dtype: float64,
#  Date
#  2017-10-03     55.00
#  2018-05-04    130.00
#  2018-10-05     60.00
#  2019-05-07    154.13
#  2019-10-07     57.00
#  2020-06-25    157.00
#  2020-10-07     27.00
#  2021-05-03     87.00
#  2021-10-08     45.00
#  2022-05-09    194.00
#  Name: Dividends, dtype: float64,
#  Date
#  2018-05-08     33.5320
#  2019-06-12     54.6075
#  2020-06-30    154.0682
#  2021-06-09    168.0100
#  Name: Dividends, dtype: float64,
#  Date
#  2018-03-23    199.02551
#  2018-03-29    199.02550
#  2019-05-27    241.21628
#  2020-02-28    353.34170
#  2021-03-24    220.27180
#  2022-03-21    360.63560
#  Name: Dividends, dtype: float64,
#  Date
#  2017-07-06     92.0
#  2017-11-30     82.0
#  2018-06-04    101.0
#  2018-11-16     82.0
#  2019-05-31    155.0
#  2019-12-03     86.0
#  2020-08-05    107.0
#  2020-12-01     87.0
#  2021-06-08    100.0
#  2021-11-30     66.0
#  Name: Dividends, dtype: float64,
#  Date
#  2018-04-02     97.04093
#  2019-05-24    120.15633
#  2020-02-27    152.90845
#  2021-04-06     89.91268
#  2022-03-11    174.25150
#  Name: Dividends, dtype: float64,
#  Date
#  2017-06-15    13.720
#  2017-12-12     6.000
#  2018-05-18    17.522
#  2018-12-17     6.000
#  2019-05-06    17.520
#  2019-12-16     6.000
#  2020-05-15    17.860
#  2020-12-15     6.000
#  2020-12-16     6.000
#  2021-06-10    22.093
#  2021-12-16     6.000
#  Name: Dividends, dtype: float64,
#  Date
#  2017-10-06    282.0
#  2018-04-24    611.0
#  2018-10-05    365.0
#  2019-04-29    828.0
#  2019-10-08    408.0
#  2020-06-22    805.0
#  2020-10-07    171.0
#  2021-04-20    473.0
#  2021-10-07    335.0
#  2022-04-20    905.0
#  Name: Dividends, dtype: float64,
#  Date
#  2017-06-12    235.0
#  2018-06-20    237.0
#  2018-11-06     65.0
#  2019-06-17    171.0
#  2020-07-24    278.0
#  2021-09-07    278.0
#  Name: Dividends, dtype: float64,
#  Date
#  2018-03-28    255.55548
#  2019-05-22    201.28955
#  2020-03-02    206.24107
#  2021-04-08     44.02262
#  2022-03-24    146.29690
#  Name: Dividends, dtype: float64]

# %%
dividends= pd.DataFrame(divs, index=tickers)

# %%
dividends.columns
# Out:
# Int64Index([2017, 2018, 2019, 2020, 2021, 2022], dtype='int64', name='Date')

# %%
dividends.columns = dividends.columns.year

# %%
dividends.columns
# Out:
# Int64Index([2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2018, 2018, 2018,
#             2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018,
#             2018, 2018, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019, 2019,
#             2019, 2019, 2019, 2019, 2019, 2019, 2020, 2020, 2020, 2020, 2020,
#             2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2021,
#             2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021, 2021,
#             2021, 2021, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='Date')

# %%
dividends
# Out:
# Date      2017   2017  2017  2017   2017  2017  2017  2017       2018  \
# BBCA.JK    NaN    NaN   NaN   NaN    NaN  16.0   NaN   NaN        NaN
# ASII.JK    NaN    NaN   NaN  55.0    NaN   NaN   NaN   NaN        NaN
# TLKM.JK    NaN    NaN   NaN   NaN    NaN   NaN   NaN   NaN        NaN
# BMRI.JK    NaN    NaN   NaN   NaN    NaN   NaN   NaN   NaN  199.02551
# UNVR.JK    NaN    NaN  92.0   NaN    NaN   NaN  82.0   NaN        NaN
# BBRI.JK    NaN    NaN   NaN   NaN    NaN   NaN   NaN   NaN        NaN
# TOWR.JK    NaN  13.72   NaN   NaN    NaN   NaN   NaN   6.0        NaN
# UNTR.JK    NaN    NaN   NaN   NaN  282.0   NaN   NaN   NaN        NaN
# INDF.JK  235.0    NaN   NaN   NaN    NaN   NaN   NaN   NaN        NaN
# BBNI.JK    NaN    NaN   NaN   NaN    NaN   NaN   NaN   NaN        NaN
#
# Date          2018  ...  2021  2021  2021  2021      2022      2022      2022  \
# BBCA.JK        NaN  ...   NaN  25.0   NaN   NaN       NaN       NaN       NaN
# ASII.JK        NaN  ...  45.0   NaN   NaN   NaN       NaN       NaN       NaN
# TLKM.JK        NaN  ...   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# BMRI.JK        NaN  ...   NaN   NaN   NaN   NaN       NaN  360.6356       NaN
# UNVR.JK        NaN  ...   NaN   NaN  66.0   NaN       NaN       NaN       NaN
# BBRI.JK        NaN  ...   NaN   NaN   NaN   NaN  174.2515       NaN       NaN
# TOWR.JK        NaN  ...   NaN   NaN   NaN   6.0       NaN       NaN       NaN
# UNTR.JK        NaN  ...   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# INDF.JK        NaN  ...   NaN   NaN   NaN   NaN       NaN       NaN       NaN
# BBNI.JK  255.55548  ...   NaN   NaN   NaN   NaN       NaN       NaN  146.2969
#
# Date      2022   2022   2022
# BBCA.JK  120.0    NaN    NaN
# ASII.JK    NaN    NaN  194.0
# TLKM.JK    NaN    NaN    NaN
# BMRI.JK    NaN    NaN    NaN
# UNVR.JK    NaN    NaN    NaN
# BBRI.JK    NaN    NaN    NaN
# TOWR.JK    NaN    NaN    NaN
# UNTR.JK    NaN  905.0    NaN
# INDF.JK    NaN    NaN    NaN
# BBNI.JK    NaN    NaN    NaN
#
# [10 rows x 74 columns]

# %% [markdown]
# ## Pembagian dividend dalam kurun waktu 5 tahun terakhir

# %%
dividends = dividends.groupby(dividends.columns, axis=1).sum()
dividends
# Out:
# Date       2017       2018        2019       2020       2021      2022
# BBCA.JK   16.00   52.00000    71.00000  110.60000  111.40000  120.0000
# ASII.JK   55.00  190.00000   211.13000  184.00000  132.00000  194.0000
# TLKM.JK    0.00   33.53200    54.60750  154.06820  168.01000    0.0000
# BMRI.JK    0.00  398.05101   241.21628  353.34170  220.27180  360.6356
# UNVR.JK  174.00  183.00000   241.00000  194.00000  166.00000    0.0000
# BBRI.JK    0.00   97.04093   120.15633  152.90845   89.91268  174.2515
# TOWR.JK   19.72   23.52200    23.52000   29.86000   28.09300    0.0000
# UNTR.JK  282.00  976.00000  1236.00000  976.00000  808.00000  905.0000
# INDF.JK  235.00  302.00000   171.00000  278.00000  278.00000    0.0000
# BBNI.JK    0.00  255.55548   201.28955  206.24107   44.02262  146.2969
